# %%
from bestbuy import BestBuyAPI

bb = BestBuyAPI("zuKN5cDvqHGmtnzEm86cff3f")

all_categories = bb.bulk.archive("categories", "json")

all_categories
# Out:
# {'categories_0001_1579550216270_to_pcmcat190000050009.json': [{'id': '1579550216270',
#    'name': 'Samsung Laundry pair message- save $440',
#    'active': False,
#    'url': 'https://www.bestbuy.com/site/promo/1579550216270?cmp=RMX-cat',
#    'path': [{'id': 'cat00000', 'name': 'Best Buy'},
#     {'id': 'abcat0900000', 'name': 'Appliances'},
#     {'id': 'abcat0910000', 'name': 'Washers & Dryers'},
#     {'id': '1579550216270',
#      'name': 'Samsung Laundry pair message- save $440'}],
#    'subCategories': []},
#   {'id': '748300000209',
#    'name': 'My Best Buy TV Calibration Offer',
#    'active': False,
#    'url': 'https://www.bestbuy.com/site/tv-home-theater-services/my-best-buy-tv-calibration-offer/748300000209.c?id=748300000209&cmp=RMX-cat',
#    'path': [{'id': 'cat00000', 'name': 'Best Buy'},
#     {'id': 'pcmcat1528819595254', 'name': 'Services'},
#     {'id': 'pcmcat138100050024', 'name': 'TV & Home Theater Services'},
# ...

# %%
from bestbuy import BestBuyAPI

bby = BestBuyAPI("zuKN5cDvqHGmtnzEm86cff3f")

data = bby.category.search_by_id(category_id="pcmcat186400050004", format="json")

data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-7fb04bdff6c6> in <module>
#       3 bby = BestBuyAPI("zuKN5cDvqHGmtnzEm86cff3f")
#       4
# ----> 5 data = bby.products.search_by_id(category_id="pcmcat186400050004", format="json")
#       6
#       7 data
#
# AttributeError: 'BestBuyProductsAPI' object has no attribute 'search_by_id'

# %%
bby.products.search(query='tv')
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<?xml-stylesheet href="/v1/xsl/xml_pretty_printer.xsl" type="text/xsl"?>\n<error>\n  <code>400</code>\n  <status>400 Bad Request</status>\n  <message>Couldn&apos;t understand &apos;/v1/products(tv)?apiKey=zuKN5cDvqHGmtnzEm86cff3f&apos;: Failed at character 16.</message>\n  <examples>\n    <example>/v1/products/8880044.xml?apiKey=&lt;YourApiKey&gt; : Get product information for sku 8880044; display as XML</example>\n    <example>/v1/stores/187.json?apiKey=&lt;YourApiKey&gt; : Get information for store 187; display as JSON</example>\n    <example>/v1/products?apiKey=&lt;YourApiKey&gt; : Get all products; show the first 10, sorted by name, display default attributes, formatted as xml</example>\n    <example>/v1/products?facet=manufacturer,10&amp;apiKey=&lt;YourApiKey&gt; : Get all products; show the first 10, sorted by name, display default attributes, formatted as xml, and display up to 10 facets based on the &quot;manufacturer&quot; field.</ex
# ...
